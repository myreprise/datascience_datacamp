# %% [markdown]
# ## **Executive Summary**

# %% [markdown]
# ## **Key Findings**
# - The dataset contains **57,194 records**, with **no missing values** across columns.
# - **29,883 entries are duplicates**, which is relevant for model-building considerations.
# - The **salary** column is redundant, as **salary_in_usd** already provides the necessary benchmark.
# - The dataset has a **recency bias toward 2024**, and most employees and companies are based in the **United States (US).**
#
# ## **Dataset Overview**
# - **Total Records:** 57,194
# - **Year Range:** 2020–2024
#   - **2024:** 81.7% of entries
#   - **2023:** 14.9% of entries
#
# ## **Salary Insights**
# - **Average Salary (USD):**
#   - **Data Engineers:** \$149,315
#   - **Data Scientists:** \$159,397
# - **Higher-Earning Role:** **Data Scientists** earn more on average.
#
# ## **Remote Work in the US**
# - **11,125 full-time US employees** work **100% remotely**.

# %% [markdown]
# ## 📖 **Background**
# You work for an international HR consultancy helping companies attract and retain top talent in the competitive tech industry. As part of your services, you provide clients with insights into industry salary trends to ensure they remain competitive in hiring and compensation practices.
#
# Your team wants to use a data-driven approach to analyse how various factors—such as job role, experience level, remote work, and company size—impact salaries globally. By understanding these trends, you can advise clients on offering competitive packages to attract the best talent.
#
# In this competition, you’ll explore and visualise salary data from thousands of employees worldwide. f you're tackling the advanced level, you'll go a step further—building predictive models to uncover key salary drivers and providing insights on how to enhance future data collection.

# %% [markdown]
# ## 💾 **Data**
#
# The data comes from a survey hosted by an HR consultancy, available in `'salaries.csv'`.
#
# #### Each row represents a single employee's salary record for a given year:
# - **`work_year`** - The year the salary was paid.
# - **`experience_level`** - Employee experience level:
#   - **`EN`**: Entry-level / Junior
#   - **`MI`**: Mid-level / Intermediate
#   - **`SE`**: Senior / Expert
#   - **`EX`**: Executive / Director
# - **`employment_type`** - Employment type:
#   - **`PT`**: Part-time
#   - **`FT`**: Full-time
#   - **`CT`**: Contract
#   - **`FL`**: Freelance
# - **`job_title`** - The job title during the year.
# - **`salary`** - Gross salary paid (in local currency).
# - **`salary_currency`** - Salary currency (ISO 4217 code).
# - **`salary_in_usd`** - Salary converted to USD using average yearly FX rate.
# - **`employee_residence`** - Employee's primary country of residence (ISO 3166 code).
# - **`remote_ratio`** - Percentage of remote work:
#   - **`0`**: No remote work (<20%)
#   - **`50`**: Hybrid (50%)
#   - **`100`**: Fully remote (>80%)
# - **`company_location`** - Employer's main office location (ISO 3166 code).
# - **`company_size`** - Company size:
#   - **`S`**: Small (<50 employees)
#   - **`M`**: Medium (50–250 employees)
#   - **`L`**: Large (>250 employees)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/salaries.csv')
df.head()
# Out:
#    work_year experience_level employment_type  job_title  salary  \
# 0       2024               MI              FT  Developer  168276
# 1       2024               MI              FT  Developer  112184
# 2       2024               EN              FT  Developer  180000
# 3       2024               EN              FT  Developer  133500
# 4       2024               EN              FT  Developer  122000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         168276                 US             0
# 1             USD         112184                 US             0
# 2             USD         180000                 US             0
# 3             USD         133500                 US             0
# 4             USD         122000                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# 3               US            M
# 4               US            M

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57194 entries, 0 to 57193
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           57194 non-null  int64
#  1   experience_level    57194 non-null  object
#  2   employment_type     57194 non-null  object
#  3   job_title           57194 non-null  object
#  4   salary              57194 non-null  int64
#  5   salary_currency     57194 non-null  object
#  6   salary_in_usd       57194 non-null  int64
#  7   employee_residence  57194 non-null  object
#  8   remote_ratio        57194 non-null  int64
#  9   company_location    57194 non-null  object
#  10  company_size        57194 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 4.8+ MB

# %%
df.describe().round(0)
# Out:
#        work_year      salary  salary_in_usd  remote_ratio
# count    57194.0     57194.0        57194.0       57194.0
# mean      2024.0    164182.0       159224.0          22.0
# std          1.0    206033.0        72155.0          41.0
# min       2020.0     14000.0        15000.0           0.0
# 25%       2024.0    109400.0       109300.0           0.0
# 50%       2024.0    149552.0       149040.0           0.0
# 75%       2024.0    200000.0       200000.0           0.0
# max       2024.0  30400000.0       800000.0         100.0

# %% [markdown]
# ## Check for missing values or incorrect entries

# %%
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# ## Check for duplication

# %%
df.duplicated().sum()
# Out:
# 29883

# %% [markdown]
# ## Check numerical data distributions

# %%
ignore_col = ['salary']
num_cols = list(df.select_dtypes(exclude='object').columns)
num_cols = [c for c in num_cols if c not in ignore_col]

for col in num_cols:
    plt.figure(figsize = (15, 6))
    plt.subplot(1, 2, 1)
    sns.boxplot(data=df, y=col)
    plt.title(col)
    plt.subplot(1, 2, 2)
    sns.histplot(data=df, x=col, kde=True)
    plt.title(col)
    plt.show()

# %%
cat_cols = list(df.select_dtypes(include='object').columns)

for col in cat_cols:
    plt.figure(figsize=(15, 6))
    sns.countplot(x=col, data=df)
    plt.title(f'Category Count for {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45)  # Rotate labels if necessary
    plt.show()

# %% [markdown]
# ## How many records are in the dataset, and what is the range of years covered?

# %%
num_records = df.shape[0]
year_range = df['work_year'].min(), df['work_year'].max()
print(f"Record count: {num_records:,.0f} records")
print(f"Year range: {year_range}")
# Out:
# Record count: 57,194 records
# Year range: (2020, 2024)

# %% [markdown]
# ## What is the average salary (in USD) for Data Scientists and Data Engineers? Which role earns more on average?

# %%
roles_of_interest = ['Data Scientist', 'Data Engineer']
avg_salary_roles = df[df['job_title'].isin(roles_of_interest)].groupby('job_title')['salary_in_usd'].mean().round(0)
roles = avg_salary_roles.index
salaries = avg_salary_roles.values
print("Salary list")
print("---------------")
for i in range(len(avg_salary_roles.values)):
    print(f"{roles[i]}: ${salaries[i]:,.0f}")
print()
print(f"On average, {roles[np.argmax(salaries)]}s earn more...")
# Out:
# Salary list
# ---------------
# Data Engineer: $149,315
# Data Scientist: $159,397
#
# On average, Data Scientists earn more...

# %% [markdown]
# ## How many full-time employees based in the US work 100% remotely?

# %%
full_time_remote_us = df[(df['employment_type'] == 'FT') & 
                         (df['employee_residence'] == 'US') & 
                         (df['remote_ratio'] == 100)].shape[0]
print(f"{full_time_remote_us:,.0f} employees")
# Out:
# 11,125 employees

# %% [markdown]
# ## What is the average salary by job title?

# %%
top = 20

plt.figure(figsize = (16, 6))

df.groupby('job_title')['salary_in_usd'].mean().sort_values(ascending = False)[:top][::-1].plot(kind = 'barh')
plt.title(f"Avg Salaries by Job Title, Top {top}")
plt.xlabel("Avg. salary")
plt.tight_layout()
